# %%
using Images
img = imread("cat.jpg")
display(img)
# Out:
# RGB Image with:
#   data: 600x400 Array{RGB{UfixedBase{Uint8,8}},2}
#   properties:
#     IMcs: RGB
#     spatialorder:  x y
#     pixelspacing:  1 1

# %%
include("main.jl")

res = ImgSeg.segment(img)
display(res)
# Out:
# RGB Image with:
#   data: 600x400 Array{RGB{UfixedBase{Uint8,8}},2}
#   properties:
#     IMcs: RGB
#     spatialorder:  x y
#     pixelspacing:  1 1
# ...
